# %%
import pandas as pd
import re

# %%
df = pd.read_csv('OncoEMR_Clearway_RxOrder_NYCBS_20240615090012.csv')

df['Patient_DOB'] = pd.to_datetime(df['Patient_DOB']).dt.strftime('%m-%d-%Y')

df['Patient_Phone_Number'] = df['Patient_Phone_Number'].apply(lambda x: re.sub(r'\D', '', str(x)))
df
# Out:
#     Patient_MRN Patient_Last_Name Patient_First_Name Patient_Middle_Name  \
# 0       3571990            Thoden               Kurt                 NaN
# 1       4030590         Raemdonck            Maureen                 NaN
# 2       4127846            Whaley             Herman                 NaN
# 3       4127846            Whaley             Herman                 NaN
# 4       4127846            Whaley             Herman                 NaN
# 5       6968794           MILILLO               VITO                 NaN
# 6       7038033             JONES              ALLAN                 NaN
# 7       7773532            Thomas             Windel                 NaN
# 8       7807499             Rowan             Doreen                 NaN
# 9       7842681               SIU             RONALD                 NaN
# 10      8053376        WHITEHOUSE              JAMES                 NaN
# 11      8077592          Gonzalez            Tatiana                   M
# ...
