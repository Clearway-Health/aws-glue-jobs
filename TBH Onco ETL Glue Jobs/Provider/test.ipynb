# %%
import pandas as pd

# %%
df = pd.read_csv('NYCBS_ONCOEMR_Provider_20240701_ 74630.csv',delimiter='|')
df['Start Date'] = pd.to_datetime(df['Start Date']).dt.strftime('%m-%d-%Y')
df['End Date'] = pd.to_datetime(df['End Date']).dt.strftime('%m-%d-%Y')
df
# Out:
#      Provider NPI          Provider Name Degree Current Status Department ID  \
# 0             NaN    CONWAY  LCSW  ALYZA    NaN         Active        NY0005
# 1             NaN    DAVEY PA-C  THERESA    NaN       Inactive        NY0005
# 2             NaN      DIALYSIS  SUFFOLK    NaN         Active        NY0005
# 3             NaN   EAPEN  MD  ELIZABETH    NaN         Active        NY0005
# 4             NaN     FELLOW  MD  CLINIC    NaN       Inactive        NY0005
# ..            ...                    ...    ...            ...           ...
# 461  1.992487e+09        WEI  NP  LEANNA    NaN         Active        NY0005
# 462  1.992704e+09       MELIS  MD  JAMES     MD         Active        NY0005
# 463  1.992741e+09      ZUHOSKI  MD  ALEX    NaN         Active        NY0005
# 464  1.992741e+09  FRANCESCHI  MD  DINKO    NaN         Active        NY0005
# 465  1.000000e+10    RADIOLOGY  REFERRED    NaN         Active        NY0005
#
#     Department Name                            Section Name  Start Date  \
# 0         PHYSICIAN                                     NaN  08-04-2023
# 1         PHYSICIAN                                     NaN  04-12-2019
# 2         PHYSICIAN                                     NaN  04-15-2024
# 3         PHYSICIAN                                     NaN  04-03-2024
# 4         PHYSICIAN                                     NaN  07-28-2021
# ..              ...                                     ...         ...
# 461       PHYSICIAN                                     NaN  02-20-2024
# 462       PHYSICIAN  Internal Medicine -- Internal Medicine  10-15-2023
# 463       PHYSICIAN                                     NaN  06-28-2024
# 464       PHYSICIAN                                     NaN  01-10-2024
# 465       PHYSICIAN                                     NaN  06-18-2024
#
#     End Date                               Specialty
# 0        NaN                                     NaN
# 1        NaN                                     NaN
# 2        NaN                                     NaN
# 3        NaN                                     NaN
# 4        NaN                                     NaN
# ..       ...                                     ...
# 461      NaN                                     NaN
# 462      NaN  Internal Medicine -- Internal Medicine
# 463      NaN                                     NaN
# 464      NaN                                     NaN
# 465      NaN                                     NaN
#
# [466 rows x 10 columns]

# %%
df.to_csv('tst.csv')
